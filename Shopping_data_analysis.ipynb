# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\Admin\Downloads\shopping_dataset.csv\shirts.csv")

# %%
df
# Out:
#     product_id                 title  \
# 0     18719236                SPYKAR
# 1     18960048  The Indian Garage Co
# 2     18960188  The Indian Garage Co
# 3     18960016  The Indian Garage Co
# 4     18996778       U.S. Polo Assn.
# ..         ...                   ...
# 92    20308620                 Arrow
# 93    18960194  The Indian Garage Co
# 94    19276504                Turtle
# 95    19299798        Louis Philippe
# 96    18903374                 Levis
#
#                                   product_description  rating  ratings_count  \
# 0                Men Blue Slim Fit Faded Casual Shirt     2.9             12
# 1              Men White & Beige Striped Casual Shirt     4.2            128
# 2   Men White & Charcoal Grey Printed Cotton Casua...     4.4             35
# 3               Men Cream-Coloured Solid Casual Shirt     4.0            102
# 4   U S Polo Assn Men Blue Gingham Checks Patch Po...     4.2             10
# ...

# %%
df.head()
# Out:
#    product_id                 title  \
# 0    18719236                SPYKAR
# 1    18960048  The Indian Garage Co
# 2    18960188  The Indian Garage Co
# 3    18960016  The Indian Garage Co
# 4    18996778       U.S. Polo Assn.
#
#                                  product_description  rating  ratings_count  \
# 0               Men Blue Slim Fit Faded Casual Shirt     2.9             12
# 1             Men White & Beige Striped Casual Shirt     4.2            128
# 2  Men White & Charcoal Grey Printed Cotton Casua...     4.4             35
# 3              Men Cream-Coloured Solid Casual Shirt     4.0            102
# 4  U S Polo Assn Men Blue Gingham Checks Patch Po...     4.2             10
#
#    initial_price  discount  final_price currency  \
# 0         2999.0      50.0  "₹1,499.00"      INR
# 1         1749.0      74.0    "₹507.00"      INR
# 2         1749.0      74.0    "₹454.00"      INR
# 3         1749.0      74.0    "₹454.00"      INR
# ...

# %%
df.tail()
# Out:
#     product_id                 title  \
# 92    20308620                 Arrow
# 93    18960194  The Indian Garage Co
# 94    19276504                Turtle
# 95    19299798        Louis Philippe
# 96    18903374                 Levis
#
#                                   product_description  rating  ratings_count  \
# 92  Men Blue Original Slim Fit Grid Tattersall Che...     4.0             59
# 93              Men White Printed Casual Cotton Shirt     3.9             73
# 94     Men Beige Printed Cotton Slim Fit Casual Shirt     4.7              7
# 95          Men Navy Blue Solid Slim Fit Formal Shirt     4.4             32
# 96                Women Blue Pure Cotton Casual Shirt     4.6            168
#
#     initial_price  discount  final_price currency  \
# 92         2499.0      50.0  "₹2,499.00"      INR
# 93         1749.0      72.0    "₹349.00"      INR
# 94         1399.0      40.0    "₹839.00"      INR
# 95         2799.0       NaN  "₹2,519.00"      INR
# ...

# %%
df.shape
# Out:
# (97, 24)

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='object')

# %%
numeric_cols = df.select_dtypes(include = ['number']).columns
df[numeric_cols] = df[numeric_cols].fillna(0)

# %%
object_cols = df.select_dtypes(include = ['object']).columns
df[object_cols] = df[object_cols].fillna("Unknown")

# %%
df = df.drop_duplicates()

# %%
df[['title', 'final_price', 'rating']]
# Out:
#                    title  final_price  rating
# 0                 SPYKAR  "₹1,499.00"     2.9
# 1   The Indian Garage Co    "₹507.00"     4.2
# 2   The Indian Garage Co    "₹454.00"     4.4
# 3   The Indian Garage Co    "₹454.00"     4.0
# 4        U.S. Polo Assn.  "₹1,559.00"     4.2
# ..                   ...          ...     ...
# 92                 Arrow  "₹2,499.00"     4.0
# 93  The Indian Garage Co    "₹349.00"     3.9
# 94                Turtle    "₹839.00"     4.7
# 95        Louis Philippe  "₹2,519.00"     4.4
# 96                 Levis  "₹2,079.00"     4.6
#
# [97 rows x 3 columns]

# %%
df[df['rating'] > 4]
# Out:
#     product_id                 title  \
# 1     18960048  The Indian Garage Co
# 2     18960188  The Indian Garage Co
# 4     18996778       U.S. Polo Assn.
# 5     18996772       U.S. Polo Assn.
# 7     18960086  The Indian Garage Co
# 12    18463946                   Lee
# 13    13621622       U.S. Polo Assn.
# 15    17719808  Louis Philippe Jeans
# 16    18759238              HERE&NOW
# 17    20394602              Cantabil
# 18    13672974                 WROGN
# 19    13694492              Ecentric
# 20    21388884     French Connection
# 22    21396820          Jack & Jones
# 23    16042682               Nautica
# 25    18996754       U.S. Polo Assn.
# 27    17296250                 CAVIO
# 29    17280264            HIGHLANDER
# 35    17307612  Louis Philippe Jeans
# 36    17345842         JC Collection
# 43    17307656   SIMON CARTER LONDON
# 44    17313630               JAINISH
# 45    17342230            Pepe Jeans
# 46    17331296              Fabindia
# ...

# %%
df['quantity'] = 1

# %%
df['total_amount'] = df['final_price'] * df['quantity']

# %%
df[['title', 'final_price', 'quantity', 'total_amount']].head()
# Out:
#                   title  final_price  quantity total_amount
# 0                SPYKAR  "₹1,499.00"         1  "₹1,499.00"
# 1  The Indian Garage Co    "₹507.00"         1    "₹507.00"
# 2  The Indian Garage Co    "₹454.00"         1    "₹454.00"
# 3  The Indian Garage Co    "₹454.00"         1    "₹454.00"
# 4       U.S. Polo Assn.  "₹1,559.00"         1  "₹1,559.00"

# %%
df.to_csv("cleaned_shirts_dataset_csv", index = False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Admin'

# %%
import os
print(os.path.abspath("cleaned_shirts_dataset_csv"))
# Out:
# C:\Users\Admin\cleaned_shirts_dataset_csv

# %% [markdown]
# 1. Loaded dataset using Pandas
# 2. Explored dataset using head(), tail(), shape, columns
# 3. Handled missing values
# 4. Removed duplicate rows
# 5. Filtered rows and selected columns
# 6. Created total_amount column
# 7. Saved cleaned dataset as CSV
